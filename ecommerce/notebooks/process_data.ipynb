# %%
from ecommerce.operations.read import ReadOperation

# %%
data = ReadOperation(path="/Users/maciej.filanowicz/ecommerce/data/Criteo_Conversion_Search/CriteoSearchData",object_format='tsv').execute()
# Out:
# /Users/maciej.filanowicz/ecommerce/ecommerce/operations/read.py:57: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._read_strategy(self.format, self.kwargs)(self.path)

# %%
data

# %%
import pandas as pd

# %%
pd.read_csv("/Users/maciej.filanowicz/ecommerce/data/Criteo_Conversion_Search/temp", sep='\t')
# Out:
#     0      -1    -1.1  1598891820  -1.2     0.0  \
# 0   0   -1.00      -1  1598925284     0    0.00
# 1   0   -1.00      -1  1598892568    -1    0.00
# 2   0   -1.00      -1  1598891174    -1    0.00
# 3   0   -1.00      -1  1598905245    -1    0.00
# 4   1   89.90  442485  1598929598     9   49.95
# 5   0   -1.00      -1  1598940008    -1    0.00
# 6   1  158.33     184  1598908235    -1  158.33
# 7   0   -1.00      -1  1598933796     1    0.00
# 8   0   -1.00      -1  1598900998   234    0.00
# 9   0   -1.00      -1  1598867812     5    0.00
# 10  0   -1.00      -1  1598891932    -1    0.00
# 11  0   -1.00      -1  1598897371    -1    0.00
# 12  0   -1.00      -1  1598924420    -1    0.00
# 13  1   38.40   60529  1598914046    -1   10.74
# 14  0   -1.00      -1  1598930658   266    0.00
# 15  0   -1.00      -1  1598896240    -1    0.00
# 16  0   -1.00      -1  1598886173    31    0.00
# 17  0   -1.00      -1  1598922740    21    0.00
# ...
